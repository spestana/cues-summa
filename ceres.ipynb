# %%
import xarray as xr
# %matplotlib inline

# %%
ceres = xr.open_dataset('CERES_EBAF-Surface_Ed4.0_Subset_200003-201803_westernCONUS.nc')

# %%
ceres
# Out:
# <xarray.Dataset>
# Dimensions:              (lat: 20, lon: 25, time: 217)
# Coordinates:
#   * lon                  (lon) float32 235.5 236.5 237.5 ... 257.5 258.5 259.5
#   * lat                  (lat) float32 30.5 31.5 32.5 33.5 ... 47.5 48.5 49.5
#   * time                 (time) datetime64[ns] 2000-03-15 ... 2018-03-15
# Data variables:
#     sfc_sw_down_all_mon  (time, lat, lon) float32 ...
#     sfc_sw_down_clr_mon  (time, lat, lon) float32 ...
#     sfc_sw_up_all_mon    (time, lat, lon) float32 ...
#     sfc_sw_up_clr_mon    (time, lat, lon) float32 ...
#     sfc_lw_down_all_mon  (time, lat, lon) float32 ...
#     sfc_lw_down_clr_mon  (time, lat, lon) float32 ...
#     sfc_lw_up_all_mon    (time, lat, lon) float32 ...
#     sfc_lw_up_clr_mon    (time, lat, lon) float32 ...
#     sfc_net_sw_all_mon   (time, lat, lon) float32 ...
#     sfc_net_sw_clr_mon   (time, lat, lon) float32 ...
#     sfc_net_lw_all_mon   (time, lat, lon) float32 ...
# ...

# %%
ceres.sfc_lw_down_all_mon[0,:,:].plot(cmap='magma')
